# %%
from matipo.sequence import Sequence

# load pulse sequence
seq = Sequence('notes.py')

seq.setpar()

# print out the parameter set for reference
print(seq.par)

# run sequence, progress_handler is optional
y = await seq.run()
# Out:
# ParameterSet()
